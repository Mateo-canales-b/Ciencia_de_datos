# %% [markdown]
# ¿Como podria una red solucionar el problema de compras de un cliente?
#
# se podria solucionar recomendando segun las compras anteriores, segun ciclos de compra, ejemplo si compra todo s los años un pavo para diciembre, le recomiendo un pavo, o cada fin de semana le recomiendo cervezas, tragos. En el caso de las familias compuestas por papá, mamá, hijos, podria recomendarle en enero los uniformes escolares, la compra mensual con un leve crecimiento mensual.

# %% [markdown]
# ¿Cuáles son los elementos fundamentales que componen una red neuronal artificial (como el perceptrón, capas de entrada, salida y capas ocultas, etc.)? Explica cada
# uno de ellos de manera sencilla.
#
#
#
# las capas de entrada seria la fecha de compra actual.
#
# las capas ocultas, la distancia temporal con la ultima compra, y la epoca del año y del mes, feriados próximos, vacaciones o eventos deportivos compras anteriores.
#
# la capa de salida sería los productos recomendados al carrito de compra dentro de la app del supermercado

# %% [markdown]
# Dado que la red neuronal se utilizará para la predicción de compras, ¿qué tipo de arquitectura considerarías para este problema? ¿Una red neuronal densa (fully connected)? ¿Por qué?
#
# si consideraría una red neuronal densa, porque la variable de entrada está muy relacionada con las capas anteriores ejemplo considerando la fecha de compra hoy, la ultima fecha de compra fue hace 3 semanas, y la persona llevó UN arroz, considero que el nucleo familiar de 4 personas en un a etapa del año que no hay vacaciones ni muchos feriados, donde se come más por el frío, es muy probable que quiera llevar otro arroz, por ende debo recomendarle uno.

# %% [markdown]
# ¿Cómo estructurarías la red neuronal para este problema? ¿Qué tamaño tendría la capa de entrada, cuántas capas ocultas serían necesarias y qué función de activación utilizarías? Explica las razones de tu elección.
#
# la capa de entrada sería una, la fecha en que está abriendo la app.
# serían necesarias dos capas como mínimo, sectores de supermercado que tienen, y cada producto que existe, Usaría una función de determinacion sigmoide. donde activamos o desactivamos el producto que se debería recomendar.

# %% [markdown]
# Parte 3: Proceso de Entrenamiento (2 puntos)
# Pregunta 5:
# ¿Qué es la función de pérdida (loss function) y por qué es importante en el entrenamiento de la red neuronal? En el contexto del caso, ¿qué tipo de función de pérdida crees que sería adecuada?
# en este caso la loss function sería interesante ya que da mas datos para analizar, en caso de que la persona lleve o no el producto recomendado.

# %% [markdown]
# Pregunta 6:
# Describe el proceso de forward pass y backpropagation. ¿Cómo ayudan estos dos conceptos a mejorar el rendimiento de la red neuronal durante el entrenamiento?

# %% [markdown]
# Parte 4: Evaluación y Mejoras (2 puntos)
# Pregunta 7:
# ¿Cómo evaluarías el desempeño de la red neuronal entrenada en este caso de predicción de compras? ¿Qué métricas usarías y por qué?
# el desemnpeño lo evaluaría con metrica de cuántos productos recomendados decidió comprar, respecto a cuantos productos compró.
# en donde 10 % de los productos comprados ya es una señal favorable y el 30 % es que el sistema está funcionando perfectamente.

# %% [markdown]
# Pregunta 8:
# Si el modelo no está funcionando correctamente, ¿qué estrategias implementarías para mejorar su desempeño? (Pueden incluir ajustes en la arquitectura, cambio de la función de pérdida, optimización de hiperparámetros, etc.).
# primero habría que determinar si el individuo es un caso execpcional o no, ya que hay veces que usan la app mas de una persona. si no es un caso excepcional cuanto se ha estado equivocando el modelo, quizás se debería bajar el umbral de activación o añadir más información

# %% [markdown]
# Parte 5: Reflexión Final (2 puntos)
# Pregunta 9:
# ¿Cuáles consideras que son las principales ventajas y desventajas de usar una red neuronal para resolver problemas como este de predicción de compras, en comparación con otros métodos tradicionales de machine learning?
#
# la principal ventaja en este sistema es que el ser humano es un animal de costumbres, en donde las compras mensuales se repiten y las cantidades varían un poco, sin embargo la principal dificultad sería los artículos nuevos que alguien quisiera comprar, ejemplo una nueva cerveza o la integración de nuevos productos en el supermercado.

# %% [markdown]
# Pregunta 10:
# Imagina que tienes que presentar este proyecto a un cliente no técnico. ¿Cómo explicarías de manera
# simple cómo funciona una red neuronal y qué tipo de resultados puede proporcionar para la
# predicción de compras?
