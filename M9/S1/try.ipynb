# %%
import sys, os
sys.path.insert(0, os.path.abspath("../../utilidades"))  # desde M*/S*/... a la raíz
from tools import *

# %%
# Ahora puedes usar las librerías directamente
print(pd.__version__)
print(np.arange(5))
plt.plot([1,2,3], [4,5,6])
plt.show()
# Out:
# 2.2.2
# [0 1 2 3 4]
